# %%
#!/usr/bin/env python
# coding: utf-8

# %% [markdown]
# In[14]:

# %%
Hrs = input("Enter your hours: ")
Rate = input("Enter your hourly rate: ")
Pay = float(Hrs) * float(Rate)
print("Pay: ",Pay)

# %% [markdown]
# In[ ]:
